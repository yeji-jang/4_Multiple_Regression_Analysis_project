# %% [markdown]
# ## 1. **[자전거 대여 횟수에 가장 큰 영향을 주는 요인은?]**

# %% [markdown]
# *   1. 기간 : 2023-05-23 ~ 2023-06-01 (총 10일)
#
#
# *   2. 리더 : 장예지
#
#
# *   3. 정의 : 공유 자전거 대여 횟수에 영향을 주는 요인분석
#
#
# *   4. 시나리오 :
#      - (1) 어떤 요인에 따라 대여횟수가 달라지는지 확인하고, 수요에 따라 자전거를 배치하고자 함.
#      - (2) 다중회귀분석을 통한 대여횟수에 영향을 주는 요인을 도출하고 이에 따른 인사이트를 얻고자 함.
#
#
# *   5. 범위:
#      - (1) 미국 워싱턴 DC의 Capital Bikeshare 시스템
#      - (2) 연도 : 2011 ~ 2012년
#      - (3) 종속변수 : 자전거 대여 횟수(cnt)
#      - (4) 독립변수 : 연/월/요일/시, 계절, 기상조건, 휴일/근무일, 온도, 습도, 풍속

# %% [markdown]
# ## 2. **[질문 정의]**

# %% [markdown]
# 1. 자전거 대여횟수가 가장 많은 년, 월, 요일, 시
# - -> 2011년보다 2012년에 자전거 대여횟수가 늘었을까?
# - -> 가장 많은 대여 횟수가 발생한 달은?
# - -> 요일별 차이가 있을까?
# - -> 출근 시간과 퇴근 시간에 자전거 대여가 많을까?
#
# 2. 휴일과 근무일의 총 자전거 대여 차이는?
# - -> 근무일의 총 자전거 대여건수가 더 많을끼?
#
# 3. 총 대여 횟수와 시즌 사이에 상관관계가 있을까?
# - -> 자전거 대여가 가장 많은 계절은 언제?
#
# 4. 자전거 대여 횟수가 기상 조건에 따른 차이가 있을까?
#
# 5. 온도, 습도, 풍속은 대여횟수에 유의미한 영향을 줄까?

# %% [markdown]
# ## 3. **[가설설정]**
# 1. 귀무가설(H0) :
# - 자전거 대여횟수는 독립 변수들과 관련이 없다.
# - 독립 변수들의 회귀 계수는 모두 0이다.
#
# 2. 대립가설(H1) :
# - 자전거 대여횟수는 적어도 하나의 독립 변수와 관련이 있다
# - 적어도 하나의 독립 변수의 회귀 계수는 0이 아니다.

# %% [markdown]
# ## 4. **[할 일 목록]**

# %% [markdown]
# - ~~1. 프로젝트 정의 및 목적 설정~~
# - ~~2. 데이터 수집 마블 api, 캐릭터 순위 스크래핑에서 uci Capital BikeshareCapital Bikeshare 으로 변경~~
# - ~~3. 데이터 이해(구조, 관계 및 특징) 및 탐색~~
# - ~~4. 변수 간 상관 관계 분석~~
# - ~~5. 다중회귀분석 수행~~
# - ~~6. 결과 해석 및 시각화~~
# - ~~7. 결과 검증 및 평가~~
# - ~~8. 피피티 발표 준비~~

# %% [markdown]
# ### **[1일차 - 5/23일]**
# 1. ~~데이터 선정 --> 영웅 캐릭터~~
# 2. ~~기존에 수집한 마블 API 외 추가로 히어로 API 데이터 수집~~

# %% [markdown]
# ### **[2일차 - 5/24일]**
# 1. ~~히어로 API 데이터 정제~~
# 2. ~~프로젝트 주제 설정 : 키가 큰 캐릭터가 스피드가 빠른가?, 몸무게가 많이 나갈 수록 힘이 더 쎈가?~~

# %% [markdown]
# ### **[3일차 - 5/25일]**
# 1. ~~프로젝트 주제 변경~~
# - ~~이유 :분석할 주제를 가지고 얻어낼 수 있는 인사이트가 부족.~~
# - ~~변경 한 주제 : 캐릭터의 인기도에 영향을 미치는 요인에 대한 분석~~
# 2. ~~캐릭터 인기도에 원인이 되는 변수 -> 등장횟수, 캐릭터 능력, 외모, 직업 등 수집시도~~
# 3. ~~종속변수 수집  -> 캐릭터 인기순위~~
# 4. 수집 못한 데이터 --> 캐릭터 등장횟수, 인기순위, 능력 분류 (셀레니움 이용 필요)

# %% [markdown]
# ### **[4일차 - 5/26일]**
# 1. 프로젝트 주제 변경
# - 셀레니움 리스크를 버리고 추후 과제로 남겨놓음
#  - ~~변경 된 주제 :~~
#  ~~(1) Bike Sharing Dataset Data Set~~
#  ~~(2) 공유 자전거 대여 횟수에 영향을 주는 요인분석~~

# %% [markdown]
# ### **[5일차 - 5/27일]**
# 1. ~~데이터 이해 및 탐색~~

# %% [markdown]
# ### **[7일차 - 5/29일]**
# -

# %% [markdown]
# ### **[8일차 - 5/30일]**
# 1. EDA 분석 --> cnt(대여횟수)와 주요 컬럼들과의 관계 시각화
# 1) ~~자전거 대여횟수가 가장 많은 년, 월, 일, 시로 나누어 확인~~
#
# 2) ~~총 대여 횟수와 시즌 사이에 상관관계가 있을까?~~
#
# 3) ~~자전거 대여 횟수가 가장 적거나 가장 많은 기상 조건은?~~
#
# 4) ~~휴일과 근무일의 총 자전거 대여 차이는?~~

# %% [markdown]
# ### **[9일차 - 5/31일]**
# 1. EDA 분석 --> cnt(대여횟수)와 주요 컬럼들과의 관계 시각화

# %% [markdown]
# ### **[10일차 - 6/1일]**
# 1. EDA 분석 --> cnt(대여횟수)와 주요 컬럼들과의 관계 시각화
# 2. t-test, ANOVA 일원분산분석, corr
# 3. 발표자료 준비 및 최종 결과물 제출

# %% [markdown]
# ## 5. **[이슈 항목 및 추후과제]**

# %% [markdown]
# ### **1. 데이터 스크래핑 수집 중 발생한 오류**

# %% [markdown]
# ~~~
# 셀레니움 이용한 스크래핑 실패 --> 주제 변경, 추후 과제로 남겨놓았습니다.
# ~~~
# - 기존의 주제 : 영웅 캐릭터 인기도에 영향을 미치는 요인은 무엇일까?
# - 히어로 캐릭터 능력, 등장횟수 및 인기도 순위에 대한 스크래핑 시도
# - request get요청하여 1~100위까지의 순위 모두 스크래핑 시도하였으나, 6위 까지만 수집 가능하였음.
# 1) 원인 : 6위 부터 스크롤이 멈춰있고 끝까지 스크롤 불가함.
# 2) 해결대책 : selenium을 이용하여 해결 가능하여, 시도하였으나 실패하였음.
# 3) 주제 변경 : 최종 프로젝트의 결과물 제출일까지 시간이 촉박하여, 리스크를 버리고 다른 데이터로 대체하였음.
# 4) 추후 계획 : selenium을 이용한 스크래핑 기술을 익혀 해결하지 못한 과제는 개인 프로젝트로 수행할 예정.
# 5) 링크
# - (1) 'https://www.ranker.com/list/superheroes-ranked-by-most-comic-book-appearances/ranker-comics'
# - (2) 'https://www.ranker.com/crowdranked-list/best-superheroes-all-time'

# %% [markdown]
# ### **2. 다중회귀분석 ols모델의 R-squared은 0.398 --> 더 나은 모델을 위한 변수 찾기 필요**

# %% [markdown]
# ~~~
# 기존 데이터셋의 독립변수들을 활용하려 ols를 작성하였을 때,
# 이에 관한 R2값은 0.398로 설명력이 작게 나왔습니다.
#
# 따라서, 자전거 대여 횟수에 영향을 주는 요인이라 판단되는 변수를 새로 찾거나
# 기존의 변수를 조합하여, 새로운 변수를 추가하여 설명력을 높일 필요가 있고 이것을 추후의 과제로 남겨놓았습니다.
# ~~~

# %% [markdown]
# ### **3. 한국 따릉이 사업에 적용할 수 있는 분석 프로젝트 필요**

# %% [markdown]
# ~~~
# 본 프로젝트에 사용된 데이터셋은 미국의 자전거 대여 서비스인 Capital Bikeshare에 대한 데이터이므로,
# 한국 따릉이의 표본이 되기 위해서 한국의 지리적 요소, 따릉이 운영방법 및 사용자 특성을 고려한 데이터 분석이 필요
# ~~~
#
# 1. 지리적 요소:
# - 미국과 한국의 기후적, 문화적, 지리적인 차이로 한국의 도시 환경과 관련된 데이터가 필요
#
# 2. 운영 모델:
# - Capital Bikeshare와 한국 따릉이는 대여 시스템, 가격 정책, 대여소 위치 등의 차이가 있을 수 있음.
#
# 3. 사용자 특성:
# - 미국인과 한국인은 대여 목적, 이동 거리, 이용 시간대 등 자전거 이용 문화와 사용자 특성은 다를 수 있음.
#
# 4. 링크 :
# - https://www.etoday.co.kr/news/view/2250875
#
# ~~~
# - 링크에서 따릉이에 대한 꾸준한 수요가 증가되고 있음을 볼 수 있습니다.
# - 따라서, Capital Bikeshare 데이터는 한국 따릉이의 표본이 되기보다는 참고 자료로 활용하며,
# - 한국 따릉이에 대한 데이터 수집과 해당 데이터를 활용한 분석을 추후과제로 남겨두었습니다.
# ~~~
