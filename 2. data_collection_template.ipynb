# %% [markdown]
# # **[공유 자전거 대여 횟수에 영향을 주는 요인분석]**

# %% [markdown]
# ## **[# 자전거 공유 데이터 세트]**

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# **hour.csv는**
# - 시간 단위로 집계된 자전거 공유 수입니다. --> 17,379시간
# - 17개의 columns와 17,379 개의 rows로 구성되어 있습니다.

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * UCI Machine Learning Repository의 데이터셋 활용
# * 홈페이지 접속 --> View ALL Data Sets --> Regression 회귀분석 카테고리
# * 자전거 공유 세트 데이터 폴더 다운로드
# * 이 데이터 세트는 Capital Bikeshare의 데이터를 사용하여 Hadi Fanaee-T에서 제공하였으며, UCI Machine Learning Repository에 올라온 데이터 세트를 호스팅 했습니다.
# * 데이터에는 null값이 존재하지 않아 정제과정을 거치지 않았습니다.

# %% [markdown]
# ### 3.   수집 경로

# %% [markdown]
# * Bike Sharing Dataset Data Set
# - URL : (https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset)

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# #### **Columns: hour_df**
# 1) instant     : 인덱스
# 2) dteday      : 날짜
# 3) season      : (1:봄, 2:여름, 3:가을, 4:겨울)
# 4) yr          : 연도(0: 2011, 1: 2012)
# 5) mnth        : 월(1 ~ 12)
# 6) hr          : 시간(0~23)
# 7) holiday     : 휴일 1, 그렇지 않은 경우 0
# 8) weekday     : 요일
# 9) workingday  : day가 주말/휴일이 아닌 경우 1, 그렇지 않은 경우 0.
# 10) weathersit : 기상 상황
# - 1: 맑고 구름이 적으며, 부분적으로 흐림, 부분적으로 흐림
# - 2: 안개 + 구름, 안개 + 구름 깨짐, 안개 + 구름 몇 개, 안개
# - 3: 가벼운 눈, 가벼운 비 + 뇌우 + 산발적인 구름, 가벼운 비 + 산발적인 구름
# - 4: 폭우 + 얼음 팔레트 + 뇌우 + 안개, 눈 + 안개
# 11) temp       : 온도(섭씨), 값은 41(최대)
# - 온도 : 섭씨 정상 온도.
# - (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39(시간 단위로만)를 통해 정규화된 값 도출.
# 12) atemp      : 체감 온도(섭씨), 값은 50(최대)
# - 체감 온도 : 섭씨로 정규화된 체감 온도.
# - (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50(시간 단위로만)을 통해 정규화된 값 도출.
# 13) hum        : 습도, 값은 100(최대)
# 14) windspeed  : 풍속, 값은 67(최대)
# 15) casual     : 캐주얼 사용자 수
# 16) registered : 등록된 사용자 수
# 17) cnt        : 총 대여 자전거 수 (캐주얼 및 등록된 사용자 모두)

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조

# %% [markdown]
# - Bike Sharing Dataset Data Set CSV 파일

# %% [markdown]
# ### 6. 참고 페이지

# %% [markdown]
# * Capital Bikeshare URL을 통해 업데이트된 데이터를 받아올 수 있습니다.
# -  URL : (https://capitalbikeshare.com/system-data)
